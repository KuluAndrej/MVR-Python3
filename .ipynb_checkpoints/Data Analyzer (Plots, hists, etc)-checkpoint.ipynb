# %%
import os, os.path, re, imp
import numpy as np
from collections import Counter
from sys import getsizeof
import time
from sklearn.preprocessing import normalize, scale, MinMaxScaler
from sklearn.cluster import *

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

from code.Primitives import *
# %matplotlib inline

# %%
plt.figure(1)
# %run ValidateFinalModel.py 'open_apple' 1
plt.figure(2)
# %run ValidateFinalModel.py 'heart_rate' 1
plt.figure(3)
# %run ValidateFinalModel.py 'chest_volume' 1
plt.figure(4)
# %run ValidateFinalModel.py 'open_apple' 2
plt.figure(3)
# %run ValidateFinalModel.py 'heart_rate' 2
plt.figure(1)
# %run ValidateFinalModel.py 'chest_volume' 2
plt.figure(5)
# %run ValidateFinalModel.py 'open_apple' 3
plt.figure(6)
# %run ValidateFinalModel.py 'heart_rate' 3
plt.figure(7)
# %run ValidateFinalModel.py 'chest_volume' 3
plt.figure(8)
# %run ValidateFinalModel.py 'open_apple' 4
plt.figure(9)
# %run ValidateFinalModel.py 'heart_rate' 4
plt.figure(10)
# %run ValidateFinalModel.py 'chest_volume' 4
plt.figure(11)
# %run ValidateFinalModel.py 'open_apple' 5
plt.figure(12)
# %run ValidateFinalModel.py 'heart_rate' 5
plt.figure(13)
# %run ValidateFinalModel.py 'chest_volume' 5
# Out:
# open_apple 1
# data.shape =  (3400, 2)
# model =  [lnl_(normal_(normal_(sina_(sina_(X[0])))))]
# optimal params=  [  1.94830916e-01   3.55402279e+01  -7.70206103e-01   3.40034508e-01
#   -2.06750752e-01   7.70727007e-01   1.15926168e-01   2.15192587e+00
#    2.41486244e-02   1.55303918e+00]
# lnl_(normal_(normal_(sina_(sina_(X[0])))))
# 0.816903959344
# heart_rate 1
# data.shape =  (3400, 2)
# model =  [linear_(normal_(sina_(normal_(sina_(X[0])))))]
# optimal params=  [ -4.99997269e+00   7.51305613e-01   2.47315459e-01   1.33733207e-01
#    9.99999754e-01   1.06154171e+01  -1.01941524e-03   5.12756200e+00
#   -8.90785365e-01   6.00877223e+00]
# linear_(normal_(sina_(normal_(sina_(X[0])))))
# 2.85330213932
# chest_volume 1
# data.shape =  (3400, 2)
# model =  [tana_(normal_(normal_(mult_(sina_(X[0])))))]
# optimal params=  [-0.82026517  3.20885368  0.8731088   2.93409707 -0.61982899  0.29801426
#   2.9916694  -0.16269883  3.36426078]
# tana_(normal_(normal_(mult_(sina_(X[0])))))
# 2.47009515696
# open_apple 2
# data.shape =  (3400, 2)
# model =  [tana_(normal_(normal_(X[0])))]
# optimal params=  [-0.99999918  4.81872286 -0.72525748  1.46864295 -0.26051045  1.21715318]
# tana_(normal_(normal_(X[0])))
# 0.778114156163
# heart_rate 2
# data.shape =  (3400, 2)
# model =  [linear_(sina_(atana_(normal_(sina_(X[0])))))]
# optimal params=  [ -4.61290615e+00   4.99999961e+00  -6.18595962e-01   1.62830036e+00
#    9.99999992e-01   8.22161282e+02  -1.69307205e-02   9.85066097e-02
#    5.96438969e-01   4.17056753e+00]
# linear_(sina_(atana_(normal_(sina_(X[0])))))
# 1.85575205184
# chest_volume 2
# data.shape =  (3400, 2)
# model =  [linear_(normal_(linear_(sina_(sina_(X[0])))))]
# optimal params=  [ -4.99999999e+00   4.99750132e+00   5.85884578e-04   9.06204932e-01
#   -2.92918734e-03   4.54971766e-01  -3.80063744e-02   4.06924577e+00
#    3.29770193e-01   4.04696418e+00]
# linear_(normal_(linear_(sina_(sina_(X[0])))))
# 2.6259919435
# open_apple 3
# data.shape =  (3400, 2)
# model =  [lnl_(normal_(sqrtl_(tana_(sina_(X[0])))))]
# optimal params=  [ 0.33323866  0.80269955  0.94852015  0.21416992  0.51041773  1.31165506
#   0.32338522  1.68019244  0.57295557  1.63146669]
# lnl_(normal_(sqrtl_(tana_(sina_(X[0])))))
# 1.35475462612
# heart_rate 3
# data.shape =  (3400, 2)
# model =  [lnl_(atana_(normal_(sina_(normal_(X[0])))))]
# optimal params=  [  1.           1.59214439  -0.34970461  13.99641838  -0.4034846    0.05
#    0.20533993   1.5          0.41695485   0.27640308]
# lnl_(atana_(normal_(sina_(normal_(X[0])))))
# 2.68661353497
# chest_volume 3
# data.shape =  (3400, 2)
# model =  [sina_(normal_(normal_(atana_(sina_(X[0])))))]
# optimal params=  [-0.51536803  1.5         0.89196031  0.40781087  0.01012296  0.05
#  -0.12575016  1.98961636 -0.06711162  3.14309301]
# sina_(normal_(normal_(atana_(sina_(X[0])))))
# 2.39396728075
# open_apple 4
# data.shape =  (3400, 2)
# model =  [lnl_(sqrtl_(X[0]))]
# optimal params=  [ 0.08338802  2.385837    0.21670436  0.24602803]
# lnl_(sqrtl_(X[0]))
# 0.754804561299
# heart_rate 4
# data.shape =  (3400, 2)
# model =  [linear_(normal_(normal_(sina_(expl_(X[0])))))]
# optimal params=  [-1.14279022  4.99999984  0.34185607  4.01425348 -0.35367868  0.35824838
#   0.21320998  1.5        -1.          2.26452624]
# linear_(normal_(normal_(sina_(expl_(X[0])))))
# 1.382830343
# chest_volume 4
# data.shape =  (3400, 2)
# model =  [linear_(sina_(sina_(sina_(plus2_(X[0],X[0])))))]
# optimal params=  [-0.13779309  0.60181427 -0.17214995  3.852033    0.40825151  2.63746564
#   0.15447265  1.94660612]
# linear_(sina_(sina_(sina_(plus2_(X[0],X[0])))))
# 3.00019579273
# open_apple 5
# data.shape =  (3400, 2)
# model =  [plus_(normal_(linear_(sina_(sina_(X[0])))))]
# optimal params=  [-0.23218817 -0.44520691  0.94686463  2.2259378   4.25030952  0.63919735
#   2.99590131  0.2650556   1.63078024]
# plus_(normal_(linear_(sina_(sina_(X[0])))))
# 1.56449011207
# heart_rate 5
# data.shape =  (3400, 2)
# model =  [plus_(sina_(sina_(sina_(normal_(X[0])))))]
# optimal params=  [ 0.15158187  1.          6.10093166  0.81436078  1.5        -0.34126029
#   1.5        -0.69141473  0.5767777 ]
# plus_(sina_(sina_(sina_(normal_(X[0])))))
# 1.26095595053
# chest_volume 5
# data.shape =  (3400, 2)
# model =  [linear_(normal_(linear_(sina_(sina_(X[0])))))]
# optimal params=  [ -4.99999931e+00   4.49905472e+00  -4.92266208e-03   8.34630649e-01
#    2.46129345e-02   3.39664990e-01  -7.78319232e-01   3.53833511e+00
#   -8.45752059e-01   4.87079433e+00]
# linear_(normal_(linear_(sina_(sina_(X[0])))))
# 2.54910454853

# %%
plt.figure(1)
# %run ValidateFinalModel.py 'open_apple' 1
plt.figure(2)
# %run ValidateFinalModel.py 'heart_rate' 1
plt.figure(4)
# %run ValidateFinalModel.py 'open_apple' 2
plt.figure(3)
# %run ValidateFinalModel.py 'heart_rate' 2
plt.figure(5)
# %run ValidateFinalModel.py 'open_apple' 3
plt.figure(6)
# %run ValidateFinalModel.py 'heart_rate' 3
plt.figure(8)
# %run ValidateFinalModel.py 'open_apple' 4
plt.figure(9)
# %run ValidateFinalModel.py 'heart_rate' 4
plt.figure(11)
# %run ValidateFinalModel.py 'open_apple' 5
plt.figure(12)
# %run ValidateFinalModel.py 'heart_rate' 5
# Out:
# open_apple 1
# data.shape =  (3400, 2)
# model =  [lnl_(sina_(normal_(times2_(linear_(X[0]),normal_(X[0])))))]
# optimal params=  [ 3.80937376  3.62528768 -1.18545667  2.39812944 -0.02835527  0.39733409
#   0.07352196  1.33459893  0.44327039  1.26768401]
# lnl_(sina_(normal_(times2_(linear_(X[0]),normal_(X[0])))))
# 0.811527317946
# heart_rate 1
# data.shape =  (3400, 2)
# model =  [linear_(normal_(linear_(sina_(sina_(X[0])))))]
# optimal params=  [ -4.99999998e+00   4.11722626e+00   1.46532938e-03   7.16562955e-01
#   -7.32680207e-03   4.23113834e-01  -2.48711757e+00   2.01752172e+00
#   -2.78115645e+00   8.03445025e+00]
# linear_(normal_(linear_(sina_(sina_(X[0])))))
# 2.86791034102
# open_apple 2
# data.shape =  (3400, 2)
# model =  [parabola_(expl_(lnl_(X[0])))]
# optimal params=  [-0.38984465  0.28291957  2.04050539 -0.44800019  2.31753967  0.24429955
#   0.93491262]
# parabola_(expl_(lnl_(X[0])))
# 0.777790299625
# heart_rate 2
# data.shape =  (3400, 2)
# model =  [lnl_(sina_(normal_(sina_(sina_(X[0])))))]
# optimal params=  [ 0.97327971  1.27435213 -5.          2.99872717 -0.5288783   0.34713207
#  -1.53119599  1.5         0.83576721  3.12665625]
# lnl_(sina_(normal_(sina_(sina_(X[0])))))
# 1.38860636543
# open_apple 3
# data.shape =  (3400, 2)
# model =  [lnl_(sina_(normal_(sina_(normal_(X[0])))))]
# optimal params=  [ -5.          11.87624935   0.4275331    1.56715141  -0.72004964
#    0.70766917  -4.18706445  14.90576866   0.62096438   2.33788032]
# lnl_(sina_(normal_(sina_(normal_(X[0])))))
# 1.41527151948
# heart_rate 3
# data.shape =  (3400, 2)
# model =  [neg_(linear_(sina_(normal_(lnl_(normal_(X[0]))))))]
# optimal params=  [-0.17018437  0.63023349 -2.05115494  1.50000442  0.81065558  0.1696167
#   2.90449755  0.5000035   0.43704239  0.05      ]
# neg_(linear_(sina_(normal_(lnl_(normal_(X[0]))))))
# 2.57740067828
# open_apple 4
# data.shape =  (3400, 2)
# model =  [plus2_(normal_(normal_(X[0])),lnl_(sina_(normal_(X[0]))))]
# optimal params=  [-0.04013087  0.44686555  0.08624771  0.47554439  0.71453096  0.71112365
#  -1.73343592  1.5         0.14716857  0.35760742]
# plus2_(normal_(normal_(X[0])),lnl_(sina_(normal_(X[0]))))
# 0.700006734317
# heart_rate 4
# data.shape =  (3400, 2)
# model =  [lnl_(normal_(sina_(sina_(expl_(X[0])))))]
# optimal params=  [-0.03885233  1.09504462  0.31995303  0.76200639  0.11321422  3.1160769
#   0.6190439   1.5242572  -0.88479554  2.02630538]
# lnl_(normal_(sina_(sina_(expl_(X[0])))))
# 1.27893505412
# open_apple 5
# data.shape =  (3400, 2)
# model =  [lnl_(linear_(normal_(sina_(sina_(X[0])))))]
# optimal params=  [ 0.30929395  0.76301159  0.35118814  0.2760606  -0.56336624  0.05
#   0.4831221   3.03015848  0.32328838  1.56430365]
# lnl_(linear_(normal_(sina_(sina_(X[0])))))
# 1.59138199595
# heart_rate 5
# data.shape =  (3400, 2)
# model =  [sina_(plus2_(sina_(normal_(X[0])),expl_(sina_(X[0]))))]
# optimal params=  [-1.14954002  1.5        -2.18225852  8.26560043  0.57104685  1.1341345
#   1.29668809  0.5        -0.75142216  2.70468269]
# sina_(plus2_(sina_(normal_(X[0])),expl_(sina_(X[0]))))
# 1.16615268737

# %%
#w = [0.75945128579027477, 1.8257602509301276, 0.47967188925467663, 1.6194614328457326, 0.4164207414652753, 0.73103167165388483, 0.98798319227210962, 0.98412347875238682]
w = [1.56142611,  1.92973782, -1.31210792,  1.        ]
x = np.linspace(-1,1,100)
#plt.plot(x,x-normal_(w[0],w[1],normal_(w[2],w[3],normal_(w[4],w[5],normal_(w[6],w[7],x)))))
model = 'linear_(w[0],w[1],sina_(w[2],w[3],sina_(w[4],w[5],sina_(w[6],w[7],normal_(w[8],w[9],x)))))'
#plt.plot(x,atana_(w[2],w[3],sina_(w[4],w[5],inv_(sqrtl_(w[6],w[7],x)))))
#plt.plot(x,normal_(w[2],w[3],normal_(w[4],w[5],sina_(w[6],w[7],sina_(w[8],w[9],plus2_(x,plus2_(x,x)))))))
plt.plot(x,linear_(w[0],w[1],sinla_(w[2],w[3],x)))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-49095efd03f7> in <module>()
#       6 #plt.plot(x,atana_(w[2],w[3],sina_(w[4],w[5],inv_(sqrtl_(w[6],w[7],x)))))
#       7 #plt.plot(x,normal_(w[2],w[3],normal_(w[4],w[5],sina_(w[6],w[7],sina_(w[8],w[9],plus2_(x,plus2_(x,x)))))))
# ----> 8 plt.plot(x,linear_(w[0],w[1],sinla_(w[2],w[3],x)))
#       9 0.779811521096
#      10 plt.show()
#
# NameError: name 'sinla_' is not defined

# %%
from pyparsing import nestedExpr
txt = "(linear_(linear_(normal_(normal_(sinha_(X[0]))))))"
nestedExpr('(',')').parseString(txt).asList()
# Out:
# [['linear_', ['linear_', ['normal_', ['normal_', ['sinha_', ['X[0]']]]]]]]

# %%
ax2 + bx + c -> 2ax + b = 0 -> x0 = -b  in [-2a,2a]

# %%
def cosh_(w0, w1, x):
    cosh_.NumParam = 2
    cosh_.NumVars = 1

    return np.cosh(x * (0.5 + abs(w1)) + w0)

x = np.linspace(-1,1,100)
plt.plot(x,normal_(w[8],w[9],x))
plt.show()

# %%
a = ([],[])
# Out:
# [1, 2, 2, 3, 4]

# %%
def expl_(w0, w1, x):
    expl_.NumParam = 2
    expl_.NumVars = 1
    return np.exp(x * w1 + w0)
w0 = 3
w1 = 3
x = np.linspace(-1,1,100)
y = expl_(w0, w1, x)
plt.plot(x,y)

# %%
plt.figure(figsize = (15,6))

b = np.loadtxt('/home/kuluandrej/Ipython3_notebook_projects/MVR_py/ts_processing/heart_rate.txt')
segment = 0
length = 70
x = np.linspace(-1,1,length)
y = b[segment*length:(segment + 1)*length]
y = y - np.mean(y, axis = 0)
y = np.divide(y, np.max(np.abs(y), axis=0))
plt.plot(x, y)
plt.figure(figsize = (15,6))
b = np.loadtxt('/home/kuluandrej/Ipython3_notebook_projects/MVR_py/ts_processing/open_apple.txt')
segment = 0
length = 70
x = np.linspace(-1,1,length)
y = b[segment*length:(segment + 1)*length]
y = y - np.mean(y, axis = 0)
y = np.divide(y, np.max(np.abs(y), axis=0))
plt.plot(x, y)

# %%
ts_labels = ['chest_volume', 'heart_rate', 'oxygen_concentration', 'open_apple']
file_path = 'ts_processing/'
number_of_rows = 3400
for ts_label in ts_labels:
    array = np.loadtxt(file_path + ts_label + '_full.txt')
    np.savetxt(file_path + ts_label + '.txt', array[0:number_of_rows], fmt = '%.3f')

# %%
dataset = pd.read_csv('/home/kuluandrej/cafedra2015-2016/Experiments on Machine Learning/Datasets/WIKI-AAPL.csv')
time_series = dataset['Open']
backup_time_series = time_series

# %%
import re
b = 'plus2_(lnl_(linear_(x0)),atana_(linear_(x0)))'
re.sub(r'x(\d+)', r'X[\1]', b)
handle = re.sub(r'X\[(\d+)\]', r'x\1', 'x0')
handle
# Out:
# 'x0'

# %%
x = np.linspace(-1,1,100)
w0 = 0
w1 = 0.2

def sqrtl_(w0, w1, x):
    sqrtl_.NumParam = 2
    sqrtl_.NumVars = 1

    return np.sqrt(np.abs(x * w1 + w0))

plt.plot(x, sqrtl_(w0, w1, x))
plt.axis([-1, 1, -1, 1])
plt.show()

# %%
files_path = 'ts_processing/'
ts_labels = ['chest_volume', 'heart_rate', 'oxygen_concentration']
ts_labels = sorted(ts_labels)

number_ts_pieces = len(os.listdir(files_path)) / len(ts_labels)
# if the number is not divided 
if abs(number_ts_pieces - round(number_ts_pieces)) > 0:
    print('ERROR: invalid number of files in ', files_path)
else:
    number_ts_pieces = int(number_ts_pieces)    

def atoi(text):
    return int(text) if text.isdigit() else text
def natural_keys(text):    
    return [ atoi(c) for c in re.split('(\d+)', text) ]

file_names = sorted(os.listdir(files_path), key=natural_keys)
# Out:
# ERROR: invalid number of files in  ts_processing/

# %%
# set of labels of ts to classify
# labels = chest_volume, heart_rate, oxygen_concentration
labels = ['chest_volume', 'heart_rate', 'oxygen_concentration']
# locations of the ts
root_path = '/MVR_py/ts_processing/'
# extension of files containing data about ts
extension = '.txt'
# folder for output files
where_to_store_models = 'collected_models2/'
# specifies number of segments for ts to be split on
number_of_segments = 340

def retrieve_ts(label):
    
    dataset_filename     = '/data/data_to_fit.txt'
    init_models_filename = '/data/init_models.txt'
    
    
    
    DATA_LOCAL_PATH = root_path
    script_dir = os.path.dirname('__file__')
    parent_dir = os.path.abspath(os.path.join(script_dir, os.pardir))
    DATA_FULL_PATH = parent_dir + DATA_LOCAL_PATH + label + extension
    # retrieve the data to fit from the specified file
    data_to_fit = np.loadtxt(DATA_FULL_PATH, delimiter = ',')
    data_to_fit = np.vstack((data_to_fit, np.linspace(0,1, len(data_to_fit)))).T
    return data_to_fit

# %%
def get_segment_of_ts(data, index_of_segment, length_of_segments):
    return data[index_of_segment * length_of_segments : (index_of_segment + 1) * length_of_segments, :]

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)

index_of_segment = 0
data = retrieve_ts('oxygen_concentration')
segment = get_segment_of_ts(data, 0, 34)
X = segment[:,1]
y = segment[:,0]

ax1.plot(X,y)

index_of_segment = 0

print("ts_label =", 'oxygen_concentration', "; index_of_segment =", index_of_segment)

data = retrieve_ts('oxygen_concentration')
segment = get_segment_of_ts(data, 1, 34)
X = segment[:,1]
y = segment[:,0]
ax2.plot(X,y)
plt.show()
# Out:
# ts_label = oxygen_concentration ; index_of_segment = 0

# %%
file = open('/home/kuluandrej/Ipython3_notebook_projects/MVR_py/ts_processing/heart_rate.txt', 'r')
data = np.loadtxt(file) 
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
f.set_figheight(8)
f.set_figwidth(15)
num_seg = 0
num_rows = 34
ax1.plot(data[num_seg * num_rows : num_seg * num_rows + num_rows,])
num_seg = 1
ax2.plot(data[num_seg * num_rows : num_seg * num_rows + num_rows,])

# %%
np.savetxt('/home/kuluandrej/Ipython3_notebook_projects/MVR_py/ts_processing/open_apple_full.txt', backup_time_series[:], fmt = '%.4f')

# %%
index_of_segment = 0
print("ts_label =", ts_labels[0], "; index_of_segment =", index_of_segment)
data = retrieve_ts(ts_labels[0])
segment = get_segment_of_ts(data, 2, int(data.shape[0] / 200))
X = segment[:,1]
y = segment[:,0]
plt.plot(X,y)
plt.show()
# Out:
# ts_label = chest_volume ; index_of_segment = 0

# %%
def atoi(text):
    return int(text) if text.isdigit() else text
def natural_keys(text):    
    return [ atoi(c) for c in re.split('(\d+)', text) ]

files_path = 'populations/first_segments2/'
file_names = sorted(os.listdir(files_path), key=natural_keys)
files_path_dest = 'populations/first_segments3/'

if not os.path.isdir(files_path_dest):
    os.makedirs(files_path_dest)

    
for file in file_names:
    number_of_file = int(file[:-4].split('_')[-1])
    if number_of_file >= 51:
        os.rename(files_path + file, files_path_dest + file)

# %%
x = np.arange(0,1,.002)
y = np.i0(x)
plt.plot(x,y)

# %% [markdown]
# Script dealing with data removing from 'init_models'

# %%
file = open('/home/kuluandrej/Ipython3_notebook_projects/MVR_py/data/init_models.txt', 'r')
lines = file.readlines()
file.close()
file = open('/home/kuluandrej/cafedra2015-2016/Experiments on Machine Learning/Datasets/WIKI-AAPL.csv', 'w')
file_dest = open()
required_rows = 5000
for i in range(required_rows):
    file.write(lines[i])
file.close()

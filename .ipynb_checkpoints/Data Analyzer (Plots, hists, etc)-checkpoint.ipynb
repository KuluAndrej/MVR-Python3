# %%
import os, os.path, re, imp
import numpy as np
from collections import Counter
from sys import getsizeof
import time
from sklearn.preprocessing import normalize, scale, MinMaxScaler
from sklearn.cluster import *
from code.modules.extract_model_tokens_encodings import extract_tokens
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

from code.Primitives import *
# %matplotlib inline

# %%
plt.figure(1)
# %run ValidateFinalModel.py 'open_apple' 1
plt.figure(2)
# %run ValidateFinalModel.py 'heart_rate' 1
plt.figure(3)
# %run ValidateFinalModel.py 'chest_volume' 1
plt.figure(4)
# %run ValidateFinalModel.py 'open_apple' 2
plt.figure(3)
# %run ValidateFinalModel.py 'heart_rate' 2
plt.figure(1)
# %run ValidateFinalModel.py 'chest_volume' 2
plt.figure(5)
# %run ValidateFinalModel.py 'open_apple' 3
plt.figure(6)
# %run ValidateFinalModel.py 'heart_rate' 3
plt.figure(7)
# %run ValidateFinalModel.py 'chest_volume' 3
plt.figure(8)
# %run ValidateFinalModel.py 'open_apple' 4
plt.figure(9)
# %run ValidateFinalModel.py 'heart_rate' 4
plt.figure(10)
# %run ValidateFinalModel.py 'chest_volume' 4
plt.figure(11)
# %run ValidateFinalModel.py 'open_apple' 5
plt.figure(12)
# %run ValidateFinalModel.py 'heart_rate' 5
plt.figure(13)
# %run ValidateFinalModel.py 'chest_volume' 5
# Out:
# open_apple 1
# data.shape =  (3400, 2)
# model =  [plus2_(normal_(sinha_(abs_(X[0]))),parabola_(plus2_(X[0],abs_(abs_(X[0])))))]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in <module>()
#      60 import sys
#      61 print(sys.argv[1], sys.argv[2])
# ---> 62 validate_final_model(sys.argv[1], int(sys.argv[2]))
#      63 #validate_final_model('heart_rate', 1)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in validate_final_model(label, index_to_observe)
#      50     population  = Parametrizer.parametrize_population(untrained_population)
#      51
# ---> 52     population = Evaluator.evaluator(population, data_to_fit, dict_tokens_info, config)
#      53     population = QualityEstimator.quality_estimator(population, data_to_fit, config)
#      54
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/Evaluator.py in evaluator(population, data_to_fit, dict_tokens_info, config)
#      52                     #, model.curve_fit_init_params, model.curve_fit_bounds
#      53                     popt, _ = curve_fit(model.def_statement, independent_var, dependent_var,\
# ---> 54                                         p0 = model.curve_fit_init_params, bounds=model.curve_fit_bounds)
#      55                 except RuntimeError:
#      56                     popt = [nan for i in range(model.number_of_parameters)]
#
# /usr/local/lib/python3.4/dist-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, **kwargs)
#     656     else:
#     657         res = least_squares(func, p0, args=args, bounds=bounds, method=method,
# --> 658                             **kwargs)
#     659
#     660         if not res.success:
#
# /usr/local/lib/python3.4/dist-packages/scipy/optimize/_lsq/least_squares.py in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     767         x0 = make_strictly_feasible(x0, lb, ub)
#     768
# --> 769     f0 = fun_wrapped(x0)
#     770
#     771     if f0.ndim != 1:
#
# /usr/local/lib/python3.4/dist-packages/scipy/optimize/_lsq/least_squares.py in fun_wrapped(x)
#     762
#     763     def fun_wrapped(x):
# --> 764         return np.atleast_1d(fun(x, *args, **kwargs))
#     765
#     766     if method == 'trf':
#
# /usr/local/lib/python3.4/dist-packages/scipy/optimize/minpack.py in _general_function(params, xdata, ydata, function)
#     451
#     452 def _general_function(params, xdata, ydata, function):
# --> 453     return function(xdata, *params) - ydata
#     454
#     455
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/DefConstructor.py in <lambda>(X, w1, w2, w3, w4, w5, w6, w7, w8, w9, w10)
#
# NameError: name 'abs_' is not defined
# heart_rate 1
# data.shape =  (3400, 2)
# model =  [linear_(plus2_(abs_(times2_(X[0],sinla_(X[0]))),sinla_(sinha_(X[0]))))]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in <module>()
#      60 import sys
#      61 print(sys.argv[1], sys.argv[2])
# ---> 62 validate_final_model(sys.argv[1], int(sys.argv[2]))
#      63 #validate_final_model('heart_rate', 1)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in validate_final_model(label, index_to_observe)
#      50     population  = Parametrizer.parametrize_population(untrained_population)
#      51
# ---> 52     population = Evaluator.evaluator(population, data_to_fit, dict_tokens_info, config)
#      53     population = QualityEstimator.quality_estimator(population, data_to_fit, config)
#      54
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/Evaluator.py in evaluator(population, data_to_fit, dict_tokens_info, config)
#      52                     #, model.curve_fit_init_params, model.curve_fit_bounds
#      53                     popt, _ = curve_fit(model.def_statement, independent_var, dependent_var,\
# ---> 54                                         p0 = model.curve_fit_init_params, bounds=model.curve_fit_bounds)
#      55                 except RuntimeError:
#      56                     popt = [nan for i in range(model.number_of_parameters)]
#
# /usr/local/lib/python3.4/dist-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, **kwargs)
#     656     else:
#     657         res = least_squares(func, p0, args=args, bounds=bounds, method=method,
# --> 658                             **kwargs)
#     659
#     660         if not res.success:
#
# /usr/local/lib/python3.4/dist-packages/scipy/optimize/_lsq/least_squares.py in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     767         x0 = make_strictly_feasible(x0, lb, ub)
#     768
# --> 769     f0 = fun_wrapped(x0)
#     770
#     771     if f0.ndim != 1:
#
# /usr/local/lib/python3.4/dist-packages/scipy/optimize/_lsq/least_squares.py in fun_wrapped(x)
#     762
#     763     def fun_wrapped(x):
# --> 764         return np.atleast_1d(fun(x, *args, **kwargs))
#     765
#     766     if method == 'trf':
#
# /usr/local/lib/python3.4/dist-packages/scipy/optimize/minpack.py in _general_function(params, xdata, ydata, function)
#     451
#     452 def _general_function(params, xdata, ydata, function):
# --> 453     return function(xdata, *params) - ydata
#     454
#     455
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/DefConstructor.py in <lambda>(X, w1, w2, w3, w4, w5, w6, w7, w8, w9)
#
# NameError: name 'abs_' is not defined
# chest_volume 1
# data.shape =  (3400, 2)
# model =  [parabola_(parabola_(normal_(sina_(X[0]))))]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in <module>()
#      60 import sys
#      61 print(sys.argv[1], sys.argv[2])
# ---> 62 validate_final_model(sys.argv[1], int(sys.argv[2]))
#      63 #validate_final_model('heart_rate', 1)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in validate_final_model(label, index_to_observe)
#      46     untrained_population = Population(initial_models[0:1])
#      47
# ---> 48     ConstructScipyOptimizeAttributes.construct_info_population(untrained_population,dict_tokens_info)
#      49
#      50     population  = Parametrizer.parametrize_population(untrained_population)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in construct_info_population(population, dict_tokens_info)
#      54     for model in population:
#      55         if not hasattr(model,'curve_fit_init_params'):
# ---> 56             p0, bounds = construct_info(model,dict_tokens_info)
#      57             setattr(model, "curve_fit_init_params", p0)
#      58             setattr(model, "curve_fit_bounds", bounds)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in construct_info(model, dict_tokens_info)
#      30     tokens_names = extract_tokens(handle).split('&')
#      31
# ---> 32     preproc_init_values = [dict_tokens_info[token][0] for token in tokens_names if not is_var(token)]
#      33     preproc_left_bounds  = [dict_tokens_info[token][1][0] for token in tokens_names if not is_var(token)]
#      34     preproc_right_bounds = [dict_tokens_info[token][1][1] for token in tokens_names if not is_var(token)]
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in <listcomp>(.0)
#      30     tokens_names = extract_tokens(handle).split('&')
#      31
# ---> 32     preproc_init_values = [dict_tokens_info[token][0] for token in tokens_names if not is_var(token)]
#      33     preproc_left_bounds  = [dict_tokens_info[token][1][0] for token in tokens_names if not is_var(token)]
#      34     preproc_right_bounds = [dict_tokens_info[token][1][1] for token in tokens_names if not is_var(token)]
#
# KeyError: 'sina_'
# open_apple 2
# data.shape =  (3400, 2)
# model =  [parabola_(expl_(lnl_(X[0])))]
# optimal params=  [-0.38984138  0.27972895  1.99631064 -0.44087599  2.31745272  0.24523837
#   0.93850532]
# parabola_(expl_(lnl_(X[0])))
# 0.777790299892
# heart_rate 2
# data.shape =  (3400, 2)
# model =  [times2_(sinha_(neg_(X[0])),parabola_(expl_(sinha_(X[0]))))]
# optimal params=  [ 1.3456222   8.35004729  3.87882437 -4.          1.          0.66483678
#   0.55869589  0.12889388  8.11793621]
# times2_(sinha_(neg_(X[0])),parabola_(expl_(sinha_(X[0]))))
# 1.37380798868
# chest_volume 2
# data.shape =  (3400, 2)
# model =  [linear_(sina_(sina_(sina_(sina_(X[0])))))]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in <module>()
#      60 import sys
#      61 print(sys.argv[1], sys.argv[2])
# ---> 62 validate_final_model(sys.argv[1], int(sys.argv[2]))
#      63 #validate_final_model('heart_rate', 1)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in validate_final_model(label, index_to_observe)
#      46     untrained_population = Population(initial_models[0:1])
#      47
# ---> 48     ConstructScipyOptimizeAttributes.construct_info_population(untrained_population,dict_tokens_info)
#      49
#      50     population  = Parametrizer.parametrize_population(untrained_population)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in construct_info_population(population, dict_tokens_info)
#      54     for model in population:
#      55         if not hasattr(model,'curve_fit_init_params'):
# ---> 56             p0, bounds = construct_info(model,dict_tokens_info)
#      57             setattr(model, "curve_fit_init_params", p0)
#      58             setattr(model, "curve_fit_bounds", bounds)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in construct_info(model, dict_tokens_info)
#      30     tokens_names = extract_tokens(handle).split('&')
#      31
# ---> 32     preproc_init_values = [dict_tokens_info[token][0] for token in tokens_names if not is_var(token)]
#      33     preproc_left_bounds  = [dict_tokens_info[token][1][0] for token in tokens_names if not is_var(token)]
#      34     preproc_right_bounds = [dict_tokens_info[token][1][1] for token in tokens_names if not is_var(token)]
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in <listcomp>(.0)
#      30     tokens_names = extract_tokens(handle).split('&')
#      31
# ---> 32     preproc_init_values = [dict_tokens_info[token][0] for token in tokens_names if not is_var(token)]
#      33     preproc_left_bounds  = [dict_tokens_info[token][1][0] for token in tokens_names if not is_var(token)]
#      34     preproc_right_bounds = [dict_tokens_info[token][1][1] for token in tokens_names if not is_var(token)]
#
# KeyError: 'sina_'
# open_apple 3
# data.shape =  (3400, 2)
# model =  [lnl_(sina_(normal_(sina_(normal_(X[0])))))]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in <module>()
#      60 import sys
#      61 print(sys.argv[1], sys.argv[2])
# ---> 62 validate_final_model(sys.argv[1], int(sys.argv[2]))
#      63 #validate_final_model('heart_rate', 1)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in validate_final_model(label, index_to_observe)
#      46     untrained_population = Population(initial_models[0:1])
#      47
# ---> 48     ConstructScipyOptimizeAttributes.construct_info_population(untrained_population,dict_tokens_info)
#      49
#      50     population  = Parametrizer.parametrize_population(untrained_population)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in construct_info_population(population, dict_tokens_info)
#      54     for model in population:
#      55         if not hasattr(model,'curve_fit_init_params'):
# ---> 56             p0, bounds = construct_info(model,dict_tokens_info)
#      57             setattr(model, "curve_fit_init_params", p0)
#      58             setattr(model, "curve_fit_bounds", bounds)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in construct_info(model, dict_tokens_info)
#      30     tokens_names = extract_tokens(handle).split('&')
#      31
# ---> 32     preproc_init_values = [dict_tokens_info[token][0] for token in tokens_names if not is_var(token)]
#      33     preproc_left_bounds  = [dict_tokens_info[token][1][0] for token in tokens_names if not is_var(token)]
#      34     preproc_right_bounds = [dict_tokens_info[token][1][1] for token in tokens_names if not is_var(token)]
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in <listcomp>(.0)
#      30     tokens_names = extract_tokens(handle).split('&')
#      31
# ---> 32     preproc_init_values = [dict_tokens_info[token][0] for token in tokens_names if not is_var(token)]
#      33     preproc_left_bounds  = [dict_tokens_info[token][1][0] for token in tokens_names if not is_var(token)]
#      34     preproc_right_bounds = [dict_tokens_info[token][1][1] for token in tokens_names if not is_var(token)]
#
# KeyError: 'sina_'
# heart_rate 3
# data.shape =  (3400, 2)
# model =  [neg_(linear_(sina_(normal_(lnl_(normal_(X[0]))))))]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in <module>()
#      60 import sys
#      61 print(sys.argv[1], sys.argv[2])
# ---> 62 validate_final_model(sys.argv[1], int(sys.argv[2]))
#      63 #validate_final_model('heart_rate', 1)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in validate_final_model(label, index_to_observe)
#      46     untrained_population = Population(initial_models[0:1])
#      47
# ---> 48     ConstructScipyOptimizeAttributes.construct_info_population(untrained_population,dict_tokens_info)
#      49
#      50     population  = Parametrizer.parametrize_population(untrained_population)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in construct_info_population(population, dict_tokens_info)
#      54     for model in population:
#      55         if not hasattr(model,'curve_fit_init_params'):
# ---> 56             p0, bounds = construct_info(model,dict_tokens_info)
#      57             setattr(model, "curve_fit_init_params", p0)
#      58             setattr(model, "curve_fit_bounds", bounds)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in construct_info(model, dict_tokens_info)
#      30     tokens_names = extract_tokens(handle).split('&')
#      31
# ---> 32     preproc_init_values = [dict_tokens_info[token][0] for token in tokens_names if not is_var(token)]
#      33     preproc_left_bounds  = [dict_tokens_info[token][1][0] for token in tokens_names if not is_var(token)]
#      34     preproc_right_bounds = [dict_tokens_info[token][1][1] for token in tokens_names if not is_var(token)]
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in <listcomp>(.0)
#      30     tokens_names = extract_tokens(handle).split('&')
#      31
# ---> 32     preproc_init_values = [dict_tokens_info[token][0] for token in tokens_names if not is_var(token)]
#      33     preproc_left_bounds  = [dict_tokens_info[token][1][0] for token in tokens_names if not is_var(token)]
#      34     preproc_right_bounds = [dict_tokens_info[token][1][1] for token in tokens_names if not is_var(token)]
#
# KeyError: 'sina_'
# chest_volume 3
# data.shape =  (3400, 2)
# model =  [linear_(normal_(sina_(sina_(normal_(X[0])))))]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in <module>()
#      60 import sys
#      61 print(sys.argv[1], sys.argv[2])
# ---> 62 validate_final_model(sys.argv[1], int(sys.argv[2]))
#      63 #validate_final_model('heart_rate', 1)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in validate_final_model(label, index_to_observe)
#      46     untrained_population = Population(initial_models[0:1])
#      47
# ---> 48     ConstructScipyOptimizeAttributes.construct_info_population(untrained_population,dict_tokens_info)
#      49
#      50     population  = Parametrizer.parametrize_population(untrained_population)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in construct_info_population(population, dict_tokens_info)
#      54     for model in population:
#      55         if not hasattr(model,'curve_fit_init_params'):
# ---> 56             p0, bounds = construct_info(model,dict_tokens_info)
#      57             setattr(model, "curve_fit_init_params", p0)
#      58             setattr(model, "curve_fit_bounds", bounds)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in construct_info(model, dict_tokens_info)
#      30     tokens_names = extract_tokens(handle).split('&')
#      31
# ---> 32     preproc_init_values = [dict_tokens_info[token][0] for token in tokens_names if not is_var(token)]
#      33     preproc_left_bounds  = [dict_tokens_info[token][1][0] for token in tokens_names if not is_var(token)]
#      34     preproc_right_bounds = [dict_tokens_info[token][1][1] for token in tokens_names if not is_var(token)]
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in <listcomp>(.0)
#      30     tokens_names = extract_tokens(handle).split('&')
#      31
# ---> 32     preproc_init_values = [dict_tokens_info[token][0] for token in tokens_names if not is_var(token)]
#      33     preproc_left_bounds  = [dict_tokens_info[token][1][0] for token in tokens_names if not is_var(token)]
#      34     preproc_right_bounds = [dict_tokens_info[token][1][1] for token in tokens_names if not is_var(token)]
#
# KeyError: 'sina_'
# open_apple 4
# data.shape =  (3400, 2)
# model =  [plus2_(normal_(normal_(X[0])),lnl_(sina_(normal_(X[0]))))]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in <module>()
#      60 import sys
#      61 print(sys.argv[1], sys.argv[2])
# ---> 62 validate_final_model(sys.argv[1], int(sys.argv[2]))
#      63 #validate_final_model('heart_rate', 1)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in validate_final_model(label, index_to_observe)
#      46     untrained_population = Population(initial_models[0:1])
#      47
# ---> 48     ConstructScipyOptimizeAttributes.construct_info_population(untrained_population,dict_tokens_info)
#      49
#      50     population  = Parametrizer.parametrize_population(untrained_population)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in construct_info_population(population, dict_tokens_info)
#      54     for model in population:
#      55         if not hasattr(model,'curve_fit_init_params'):
# ---> 56             p0, bounds = construct_info(model,dict_tokens_info)
#      57             setattr(model, "curve_fit_init_params", p0)
#      58             setattr(model, "curve_fit_bounds", bounds)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in construct_info(model, dict_tokens_info)
#      30     tokens_names = extract_tokens(handle).split('&')
#      31
# ---> 32     preproc_init_values = [dict_tokens_info[token][0] for token in tokens_names if not is_var(token)]
#      33     preproc_left_bounds  = [dict_tokens_info[token][1][0] for token in tokens_names if not is_var(token)]
#      34     preproc_right_bounds = [dict_tokens_info[token][1][1] for token in tokens_names if not is_var(token)]
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in <listcomp>(.0)
#      30     tokens_names = extract_tokens(handle).split('&')
#      31
# ---> 32     preproc_init_values = [dict_tokens_info[token][0] for token in tokens_names if not is_var(token)]
#      33     preproc_left_bounds  = [dict_tokens_info[token][1][0] for token in tokens_names if not is_var(token)]
#      34     preproc_right_bounds = [dict_tokens_info[token][1][1] for token in tokens_names if not is_var(token)]
#
# KeyError: 'sina_'
# heart_rate 4
# data.shape =  (3400, 2)
# model =  [lnl_(normal_(sina_(sina_(expl_(X[0])))))]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in <module>()
#      60 import sys
#      61 print(sys.argv[1], sys.argv[2])
# ---> 62 validate_final_model(sys.argv[1], int(sys.argv[2]))
#      63 #validate_final_model('heart_rate', 1)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in validate_final_model(label, index_to_observe)
#      46     untrained_population = Population(initial_models[0:1])
#      47
# ---> 48     ConstructScipyOptimizeAttributes.construct_info_population(untrained_population,dict_tokens_info)
#      49
#      50     population  = Parametrizer.parametrize_population(untrained_population)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in construct_info_population(population, dict_tokens_info)
#      54     for model in population:
#      55         if not hasattr(model,'curve_fit_init_params'):
# ---> 56             p0, bounds = construct_info(model,dict_tokens_info)
#      57             setattr(model, "curve_fit_init_params", p0)
#      58             setattr(model, "curve_fit_bounds", bounds)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in construct_info(model, dict_tokens_info)
#      30     tokens_names = extract_tokens(handle).split('&')
#      31
# ---> 32     preproc_init_values = [dict_tokens_info[token][0] for token in tokens_names if not is_var(token)]
#      33     preproc_left_bounds  = [dict_tokens_info[token][1][0] for token in tokens_names if not is_var(token)]
#      34     preproc_right_bounds = [dict_tokens_info[token][1][1] for token in tokens_names if not is_var(token)]
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in <listcomp>(.0)
#      30     tokens_names = extract_tokens(handle).split('&')
#      31
# ---> 32     preproc_init_values = [dict_tokens_info[token][0] for token in tokens_names if not is_var(token)]
#      33     preproc_left_bounds  = [dict_tokens_info[token][1][0] for token in tokens_names if not is_var(token)]
#      34     preproc_right_bounds = [dict_tokens_info[token][1][1] for token in tokens_names if not is_var(token)]
#
# KeyError: 'sina_'
# chest_volume 4
# data.shape =  (3400, 2)
# model =  [parabola_(normal_(parabola_(sina_(X[0]))))]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in <module>()
#      60 import sys
#      61 print(sys.argv[1], sys.argv[2])
# ---> 62 validate_final_model(sys.argv[1], int(sys.argv[2]))
#      63 #validate_final_model('heart_rate', 1)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in validate_final_model(label, index_to_observe)
#      46     untrained_population = Population(initial_models[0:1])
#      47
# ---> 48     ConstructScipyOptimizeAttributes.construct_info_population(untrained_population,dict_tokens_info)
#      49
#      50     population  = Parametrizer.parametrize_population(untrained_population)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in construct_info_population(population, dict_tokens_info)
#      54     for model in population:
#      55         if not hasattr(model,'curve_fit_init_params'):
# ---> 56             p0, bounds = construct_info(model,dict_tokens_info)
#      57             setattr(model, "curve_fit_init_params", p0)
#      58             setattr(model, "curve_fit_bounds", bounds)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in construct_info(model, dict_tokens_info)
#      30     tokens_names = extract_tokens(handle).split('&')
#      31
# ---> 32     preproc_init_values = [dict_tokens_info[token][0] for token in tokens_names if not is_var(token)]
#      33     preproc_left_bounds  = [dict_tokens_info[token][1][0] for token in tokens_names if not is_var(token)]
#      34     preproc_right_bounds = [dict_tokens_info[token][1][1] for token in tokens_names if not is_var(token)]
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in <listcomp>(.0)
#      30     tokens_names = extract_tokens(handle).split('&')
#      31
# ---> 32     preproc_init_values = [dict_tokens_info[token][0] for token in tokens_names if not is_var(token)]
#      33     preproc_left_bounds  = [dict_tokens_info[token][1][0] for token in tokens_names if not is_var(token)]
#      34     preproc_right_bounds = [dict_tokens_info[token][1][1] for token in tokens_names if not is_var(token)]
#
# KeyError: 'sina_'
# open_apple 5
# data.shape =  (3400, 2)
# model =  [lnl_(linear_(normal_(sina_(sina_(X[0])))))]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in <module>()
#      60 import sys
#      61 print(sys.argv[1], sys.argv[2])
# ---> 62 validate_final_model(sys.argv[1], int(sys.argv[2]))
#      63 #validate_final_model('heart_rate', 1)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in validate_final_model(label, index_to_observe)
#      46     untrained_population = Population(initial_models[0:1])
#      47
# ---> 48     ConstructScipyOptimizeAttributes.construct_info_population(untrained_population,dict_tokens_info)
#      49
#      50     population  = Parametrizer.parametrize_population(untrained_population)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in construct_info_population(population, dict_tokens_info)
#      54     for model in population:
#      55         if not hasattr(model,'curve_fit_init_params'):
# ---> 56             p0, bounds = construct_info(model,dict_tokens_info)
#      57             setattr(model, "curve_fit_init_params", p0)
#      58             setattr(model, "curve_fit_bounds", bounds)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in construct_info(model, dict_tokens_info)
#      30     tokens_names = extract_tokens(handle).split('&')
#      31
# ---> 32     preproc_init_values = [dict_tokens_info[token][0] for token in tokens_names if not is_var(token)]
#      33     preproc_left_bounds  = [dict_tokens_info[token][1][0] for token in tokens_names if not is_var(token)]
#      34     preproc_right_bounds = [dict_tokens_info[token][1][1] for token in tokens_names if not is_var(token)]
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in <listcomp>(.0)
#      30     tokens_names = extract_tokens(handle).split('&')
#      31
# ---> 32     preproc_init_values = [dict_tokens_info[token][0] for token in tokens_names if not is_var(token)]
#      33     preproc_left_bounds  = [dict_tokens_info[token][1][0] for token in tokens_names if not is_var(token)]
#      34     preproc_right_bounds = [dict_tokens_info[token][1][1] for token in tokens_names if not is_var(token)]
#
# KeyError: 'sina_'
# heart_rate 5
# data.shape =  (3400, 2)
# model =  [sina_(plus2_(sina_(normal_(X[0])),expl_(sina_(X[0]))))]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in <module>()
#      60 import sys
#      61 print(sys.argv[1], sys.argv[2])
# ---> 62 validate_final_model(sys.argv[1], int(sys.argv[2]))
#      63 #validate_final_model('heart_rate', 1)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in validate_final_model(label, index_to_observe)
#      46     untrained_population = Population(initial_models[0:1])
#      47
# ---> 48     ConstructScipyOptimizeAttributes.construct_info_population(untrained_population,dict_tokens_info)
#      49
#      50     population  = Parametrizer.parametrize_population(untrained_population)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in construct_info_population(population, dict_tokens_info)
#      54     for model in population:
#      55         if not hasattr(model,'curve_fit_init_params'):
# ---> 56             p0, bounds = construct_info(model,dict_tokens_info)
#      57             setattr(model, "curve_fit_init_params", p0)
#      58             setattr(model, "curve_fit_bounds", bounds)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in construct_info(model, dict_tokens_info)
#      30     tokens_names = extract_tokens(handle).split('&')
#      31
# ---> 32     preproc_init_values = [dict_tokens_info[token][0] for token in tokens_names if not is_var(token)]
#      33     preproc_left_bounds  = [dict_tokens_info[token][1][0] for token in tokens_names if not is_var(token)]
#      34     preproc_right_bounds = [dict_tokens_info[token][1][1] for token in tokens_names if not is_var(token)]
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/ConstructScipyOptimizeAttributes.py in <listcomp>(.0)
#      30     tokens_names = extract_tokens(handle).split('&')
#      31
# ---> 32     preproc_init_values = [dict_tokens_info[token][0] for token in tokens_names if not is_var(token)]
#      33     preproc_left_bounds  = [dict_tokens_info[token][1][0] for token in tokens_names if not is_var(token)]
#      34     preproc_right_bounds = [dict_tokens_info[token][1][1] for token in tokens_names if not is_var(token)]
#
# KeyError: 'sina_'
# chest_volume 5
# data.shape =  (3400, 2)
# model =  [parabola_(parabola_(normal_(frac2_(normal_(X[0]),X[0]))))]
# optimal params=  [-0.336071   -0.3157463   1.00000011 -0.37727816 -1.13992693  1.00000115
#   0.33821969  0.51242529  0.11803389  0.36703659]
# parabola_(parabola_(normal_(frac2_(normal_(X[0]),X[0]))))
# 2.92260954188

# %%
plt.figure(1)
# %run ValidateFinalModel.py 'open_apple' 1
plt.figure(2)
# %run ValidateFinalModel.py 'heart_rate' 1
# Out:
# open_apple 1
# data.shape =  (3400, 2)
# model =  [plus2_(normal_(sinha_(abs_(X[0]))),parabola_(plus2_(X[0],abs_(abs_(X[0])))))]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in <module>()
#      60 import sys
#      61 print(sys.argv[1], sys.argv[2])
# ---> 62 validate_final_model(sys.argv[1], int(sys.argv[2]))
#      63 #validate_final_model('heart_rate', 1)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in validate_final_model(label, index_to_observe)
#      50     population  = Parametrizer.parametrize_population(untrained_population)
#      51
# ---> 52     population = Evaluator.evaluator(population, data_to_fit, dict_tokens_info, config)
#      53     population = QualityEstimator.quality_estimator(population, data_to_fit, config)
#      54
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/Evaluator.py in evaluator(population, data_to_fit, dict_tokens_info, config)
#      52                     #, model.curve_fit_init_params, model.curve_fit_bounds
#      53                     popt, _ = curve_fit(model.def_statement, independent_var, dependent_var,\
# ---> 54                                         p0 = model.curve_fit_init_params, bounds=model.curve_fit_bounds)
#      55                 except RuntimeError:
#      56                     popt = [nan for i in range(model.number_of_parameters)]
#
# /usr/local/lib/python3.4/dist-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, **kwargs)
#     656     else:
#     657         res = least_squares(func, p0, args=args, bounds=bounds, method=method,
# --> 658                             **kwargs)
#     659
#     660         if not res.success:
#
# /usr/local/lib/python3.4/dist-packages/scipy/optimize/_lsq/least_squares.py in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     767         x0 = make_strictly_feasible(x0, lb, ub)
#     768
# --> 769     f0 = fun_wrapped(x0)
#     770
#     771     if f0.ndim != 1:
#
# /usr/local/lib/python3.4/dist-packages/scipy/optimize/_lsq/least_squares.py in fun_wrapped(x)
#     762
#     763     def fun_wrapped(x):
# --> 764         return np.atleast_1d(fun(x, *args, **kwargs))
#     765
#     766     if method == 'trf':
#
# /usr/local/lib/python3.4/dist-packages/scipy/optimize/minpack.py in _general_function(params, xdata, ydata, function)
#     451
#     452 def _general_function(params, xdata, ydata, function):
# --> 453     return function(xdata, *params) - ydata
#     454
#     455
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/DefConstructor.py in <lambda>(X, w1, w2, w3, w4, w5, w6, w7, w8, w9, w10)
#
# NameError: name 'abs_' is not defined
# heart_rate 1
# data.shape =  (3400, 2)
# model =  [linear_(plus2_(abs_(times2_(X[0],sinla_(X[0]))),sinla_(sinha_(X[0]))))]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in <module>()
#      60 import sys
#      61 print(sys.argv[1], sys.argv[2])
# ---> 62 validate_final_model(sys.argv[1], int(sys.argv[2]))
#      63 #validate_final_model('heart_rate', 1)
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/ValidateFinalModel.py in validate_final_model(label, index_to_observe)
#      50     population  = Parametrizer.parametrize_population(untrained_population)
#      51
# ---> 52     population = Evaluator.evaluator(population, data_to_fit, dict_tokens_info, config)
#      53     population = QualityEstimator.quality_estimator(population, data_to_fit, config)
#      54
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/Evaluator.py in evaluator(population, data_to_fit, dict_tokens_info, config)
#      52                     #, model.curve_fit_init_params, model.curve_fit_bounds
#      53                     popt, _ = curve_fit(model.def_statement, independent_var, dependent_var,\
# ---> 54                                         p0 = model.curve_fit_init_params, bounds=model.curve_fit_bounds)
#      55                 except RuntimeError:
#      56                     popt = [nan for i in range(model.number_of_parameters)]
#
# /usr/local/lib/python3.4/dist-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, **kwargs)
#     656     else:
#     657         res = least_squares(func, p0, args=args, bounds=bounds, method=method,
# --> 658                             **kwargs)
#     659
#     660         if not res.success:
#
# /usr/local/lib/python3.4/dist-packages/scipy/optimize/_lsq/least_squares.py in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     767         x0 = make_strictly_feasible(x0, lb, ub)
#     768
# --> 769     f0 = fun_wrapped(x0)
#     770
#     771     if f0.ndim != 1:
#
# /usr/local/lib/python3.4/dist-packages/scipy/optimize/_lsq/least_squares.py in fun_wrapped(x)
#     762
#     763     def fun_wrapped(x):
# --> 764         return np.atleast_1d(fun(x, *args, **kwargs))
#     765
#     766     if method == 'trf':
#
# /usr/local/lib/python3.4/dist-packages/scipy/optimize/minpack.py in _general_function(params, xdata, ydata, function)
#     451
#     452 def _general_function(params, xdata, ydata, function):
# --> 453     return function(xdata, *params) - ydata
#     454
#     455
#
# /home/kuluandrej/Ipython3_notebook_projects/MVR_py/code/DefConstructor.py in <lambda>(X, w1, w2, w3, w4, w5, w6, w7, w8, w9)
#
# NameError: name 'abs_' is not defined

# %%
#w = [0.75945128579027477, 1.8257602509301276, 0.47967188925467663, 1.6194614328457326, 0.4164207414652753, 0.73103167165388483, 0.98798319227210962, 0.98412347875238682]
w = [-0.5422442,   0.20000002,  0.27331518,  0.15540381,  0.77703581,  0.05,
  0.09513913,  3.87660442,  0.04840842,  8.22082254]
x = np.linspace(-1,1,100)
#plt.plot(x,x-normal_(w[0],w[1],normal_(w[2],w[3],normal_(w[4],w[5],normal_(w[6],w[7],x)))))
model = 'linear_(w[0],w[1],normal_(w[2],w[3],normal_(w[4],w[5],sinla_(w[6],w[7],sinha_(w[8],w[9],x)))))'

#plt.plot(x,atana_(w[2],w[3],sina_(w[4],w[5],inv_(sqrtl_(w[6],w[7],x)))))
#plt.plot(x,normal_(w[2],w[3],normal_(w[4],w[5],sina_(w[6],w[7],sina_(w[8],w[9],plus2_(x,plus2_(x,x)))))))
plt.plot(x,normal_(w[4],w[5],x))
plt.show()

# %%
from pyparsing import nestedExpr
txt = "(linear_(linear_(normal_(normal_(sinha_(X[0]))))))"
nst = nestedExpr('(',')').parseString(txt).asList()
import itertools
merged = list(itertools.chain(*nst))
merged
# Out:
# (linear_&linear_&normal_&normal_&sinha_
# ['linear_', ['linear_', ['normal_', ['normal_', ['sinha_', ['X[0]']]]]]]

# %%
ax2 + bx + c -> 2ax + b = 0 -> x0 = -b  in [-2a,2a]

# %%
def cosh_(w0, w1, x):
    cosh_.NumParam = 2
    cosh_.NumVars = 1

    return np.cosh(x * (0.5 + abs(w1)) + w0)

x = np.linspace(-1,1,100)
plt.plot(x,normal_(w[8],w[9],x))
plt.show()

# %%
a = ([],[])
# Out:
# [1, 2, 2, 3, 4]

# %%
def expl_(w0, w1, x):
    expl_.NumParam = 2
    expl_.NumVars = 1
    return np.exp(x * w1 + w0)
w0 = 3
w1 = 3
x = np.linspace(-1,1,100)
y = expl_(w0, w1, x)
plt.plot(x,y)

# %%
plt.figure(figsize = (15,6))

b = np.loadtxt('/home/kuluandrej/Ipython3_notebook_projects/MVR_py/ts_processing/heart_rate.txt')
segment = 0
length = 70
x = np.linspace(-1,1,length)
y = b[segment*length:(segment + 1)*length]
y = y - np.mean(y, axis = 0)
y = np.divide(y, np.max(np.abs(y), axis=0))
plt.plot(x, y)
plt.figure(figsize = (15,6))
b = np.loadtxt('/home/kuluandrej/Ipython3_notebook_projects/MVR_py/ts_processing/open_apple.txt')
segment = 0
length = 70
x = np.linspace(-1,1,length)
y = b[segment*length:(segment + 1)*length]
y = y - np.mean(y, axis = 0)
y = np.divide(y, np.max(np.abs(y), axis=0))
plt.plot(x, y)

# %%
ts_labels = ['chest_volume', 'heart_rate', 'oxygen_concentration', 'open_apple']
file_path = 'ts_processing/'
number_of_rows = 3400
for ts_label in ts_labels:
    array = np.loadtxt(file_path + ts_label + '_full.txt')
    np.savetxt(file_path + ts_label + '.txt', array[0:number_of_rows], fmt = '%.3f')

# %%
dataset = pd.read_csv('/home/kuluandrej/cafedra2015-2016/Experiments on Machine Learning/Datasets/WIKI-AAPL.csv')
time_series = dataset['Open']
backup_time_series = time_series

# %%
import re
b = 'plus2_(lnl_(linear_(x0)),atana_(linear_(x0)))'
re.sub(r'x(\d+)', r'X[\1]', b)
handle = re.sub(r'X\[(\d+)\]', r'x\1', 'x0')
handle
# Out:
# 'x0'

# %%
x = np.linspace(-1,1,100)
w0 = 0
w1 = 0.2

def sqrtl_(w0, w1, x):
    sqrtl_.NumParam = 2
    sqrtl_.NumVars = 1

    return np.sqrt(np.abs(x * w1 + w0))

plt.plot(x, sqrtl_(w0, w1, x))
plt.axis([-1, 1, -1, 1])
plt.show()

# %%
files_path = 'ts_processing/'
ts_labels = ['chest_volume', 'heart_rate', 'oxygen_concentration']
ts_labels = sorted(ts_labels)

number_ts_pieces = len(os.listdir(files_path)) / len(ts_labels)
# if the number is not divided 
if abs(number_ts_pieces - round(number_ts_pieces)) > 0:
    print('ERROR: invalid number of files in ', files_path)
else:
    number_ts_pieces = int(number_ts_pieces)    

def atoi(text):
    return int(text) if text.isdigit() else text
def natural_keys(text):    
    return [ atoi(c) for c in re.split('(\d+)', text) ]

file_names = sorted(os.listdir(files_path), key=natural_keys)
# Out:
# ERROR: invalid number of files in  ts_processing/

# %%
# set of labels of ts to classify
# labels = chest_volume, heart_rate, oxygen_concentration
labels = ['chest_volume', 'heart_rate', 'oxygen_concentration']
# locations of the ts
root_path = '/MVR_py/ts_processing/'
# extension of files containing data about ts
extension = '.txt'
# folder for output files
where_to_store_models = 'collected_models2/'
# specifies number of segments for ts to be split on
number_of_segments = 340

def retrieve_ts(label):
    
    dataset_filename     = '/data/data_to_fit.txt'
    init_models_filename = '/data/init_models.txt'
    
    
    
    DATA_LOCAL_PATH = root_path
    script_dir = os.path.dirname('__file__')
    parent_dir = os.path.abspath(os.path.join(script_dir, os.pardir))
    DATA_FULL_PATH = parent_dir + DATA_LOCAL_PATH + label + extension
    # retrieve the data to fit from the specified file
    data_to_fit = np.loadtxt(DATA_FULL_PATH, delimiter = ',')
    data_to_fit = np.vstack((data_to_fit, np.linspace(0,1, len(data_to_fit)))).T
    return data_to_fit

# %%
def get_segment_of_ts(data, index_of_segment, length_of_segments):
    return data[index_of_segment * length_of_segments : (index_of_segment + 1) * length_of_segments, :]

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)

index_of_segment = 0
data = retrieve_ts('oxygen_concentration')
segment = get_segment_of_ts(data, 0, 34)
X = segment[:,1]
y = segment[:,0]

ax1.plot(X,y)

index_of_segment = 0

print("ts_label =", 'oxygen_concentration', "; index_of_segment =", index_of_segment)

data = retrieve_ts('oxygen_concentration')
segment = get_segment_of_ts(data, 1, 34)
X = segment[:,1]
y = segment[:,0]
ax2.plot(X,y)
plt.show()
# Out:
# ts_label = oxygen_concentration ; index_of_segment = 0

# %%
file = open('/home/kuluandrej/Ipython3_notebook_projects/MVR_py/ts_processing/heart_rate.txt', 'r')
data = np.loadtxt(file) 
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
f.set_figheight(8)
f.set_figwidth(15)
num_seg = 0
num_rows = 34
ax1.plot(data[num_seg * num_rows : num_seg * num_rows + num_rows,])
num_seg = 1
ax2.plot(data[num_seg * num_rows : num_seg * num_rows + num_rows,])

# %%
np.savetxt('/home/kuluandrej/Ipython3_notebook_projects/MVR_py/ts_processing/open_apple_full.txt', backup_time_series[:], fmt = '%.4f')

# %%
index_of_segment = 0
print("ts_label =", ts_labels[0], "; index_of_segment =", index_of_segment)
data = retrieve_ts(ts_labels[0])
segment = get_segment_of_ts(data, 2, int(data.shape[0] / 200))
X = segment[:,1]
y = segment[:,0]
plt.plot(X,y)
plt.show()
# Out:
# ts_label = chest_volume ; index_of_segment = 0

# %%
def atoi(text):
    return int(text) if text.isdigit() else text
def natural_keys(text):    
    return [ atoi(c) for c in re.split('(\d+)', text) ]

files_path = 'populations/first_segments2/'
file_names = sorted(os.listdir(files_path), key=natural_keys)
files_path_dest = 'populations/first_segments3/'

if not os.path.isdir(files_path_dest):
    os.makedirs(files_path_dest)

    
for file in file_names:
    number_of_file = int(file[:-4].split('_')[-1])
    if number_of_file >= 51:
        os.rename(files_path + file, files_path_dest + file)

# %%
x = np.arange(0,1,.002)
y = np.i0(x)
plt.plot(x,y)

# %% [markdown]
# Script dealing with data removing from 'init_models'

# %%
file = open('/home/kuluandrej/Ipython3_notebook_projects/MVR_py/data/init_models.txt', 'r')
lines = file.readlines()
file.close()
file = open('/home/kuluandrej/cafedra2015-2016/Experiments on Machine Learning/Datasets/WIKI-AAPL.csv', 'w')
file_dest = open()
required_rows = 5000
for i in range(required_rows):
    file.write(lines[i])
file.close()
